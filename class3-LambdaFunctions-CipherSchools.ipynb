# %%
# lambda expressions

# %%
lambda a, b: a + b
# Out:
# <function __main__.<lambda>(a, b)>

# %%
print("Hello World")
# Out:
# Hello World

# %%
show = print
show("something")
# Out:
# something

# %%
names = ["komal", "samantha", "rakul"]
for name in names:
  print(name)
# Out:
# komal
# samantha
# rakul

# %%
names = ["komal", "samantha", "rakul"]
for name in enumerate(names):
  print(name)
# Out:
# (0, 'komal')
# (1, 'samantha')
# (2, 'rakul')

# %%
int a[] = {1, 2, 3}

# %%
a = 5
b = 9
